# %%
import sys

sys.path.append("..")

from plasma_separation.ion_trajectory import import_from_comsol_file, get_color_for_ion, animate_trajectories_2d
from matplotlib import pyplot as plt
import matplotlib.animation as animation

# %%
traj = import_from_comsol_file("ion_trajectories_comsol.csv")

# %%
fig, ax = plt.subplots(figsize=(8, 8))

data = traj.poses[:, :, :2]  # Extract XY positions
colors = [get_color_for_ion(ion) for ion in traj]

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

ani = animate_trajectories_2d(ax, data, colors, frames_per_second=24)

plt.show()

# %%
1 / (20e-6)
